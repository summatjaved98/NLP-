# %%
from pyspark.sql import SparkSession
spark= SparkSession.builder.appName('nlp').getOrCreate()

# %%
from pyspark.ml.feature import HashingTF,IDF,Tokenizer

# %%
senData = spark.createDataFrame([
     (0.0,'hi i heard about spark'),(0.0,'i wish java could use case classes'),(1.0,'logistic,regressions,models,are,neat')],['label','sentence'])
senData.show()
# Out:
# +-----+--------------------+
# |label|            sentence|
# +-----+--------------------+
# |  0.0|hi i heard about ...|
# |  0.0|i wish java could...|
# |  1.0|logistic,regressi...|
# +-----+--------------------+

# %%
tokenizer = Tokenizer(inputCol='sentence',outputCol='words') 
words_data = tokenizer.transform(senData)
words_data.show()
# Out:
# +-----+--------------------+--------------------+
# |label|            sentence|               words|
# +-----+--------------------+--------------------+
# |  0.0|hi i heard about ...|[hi, i, heard, ab...|
# |  0.0|i wish java could...|[i, wish, java, c...|
# |  1.0|logistic,regressi...|[logistic,regress...|
# +-----+--------------------+--------------------+

# %%
hashing_tf = HashingTF(inputCol='words', outputCol='raw features')

# %%
featurized_data = hashing_tf.transform(words_data)

# %%
idf = IDF(inputCol='raw features', outputCol='features')

# %%
idf_model = idf.fit(featurized_data)

# %%
rescaled_data = idf_model.transform(featurized_data)
rescaled_data.select('label','features').show()
# Out:
# +-----+--------------------+
# |label|            features|
# +-----+--------------------+
# |  0.0|(262144,[18700,19...|
# |  0.0|(262144,[19036,20...|
# |  1.0|(262144,[171074],...|
# +-----+--------------------+

# %%
from pyspark.ml.feature import CountVectorizer

# %%
df = spark.createDataFrame([(0, "a b c".split(' ')),(1,'a b b c a'.split(' '))], ['id','words'])

# %%
df.show()
# Out:
# +---+---------------+
# | id|          words|
# +---+---------------+
# |  0|      [a, b, c]|
# |  1|[a, b, b, c, a]|
# +---+---------------+

# %%
cv = CountVectorizer(inputCol ='words',outputCol='features',vocabSize=3,minDF=2.0)

# %%
model=cv.fit(df)

# %%
result=model.transform(df)

# %%
result.show(truncate= False)
# Out:
# +---+---------------+-------------------------+
# |id |words          |features                 |
# +---+---------------+-------------------------+
# |0  |[a, b, c]      |(3,[0,1,2],[1.0,1.0,1.0])|
# |1  |[a, b, b, c, a]|(3,[0,1,2],[2.0,2.0,1.0])|
# +---+---------------+-------------------------+
